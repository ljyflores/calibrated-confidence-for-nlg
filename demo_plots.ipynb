# %%
import matplotlib.pyplot as plt
from utils_tail_probs import *

# %%
bars0 = [0.09] * 10 + [0.01] * 10
barlist = plt.bar(list(range(1, len(bars0) + 1)), bars0)
# for i in range(10):
#     if i in [2, 4, 7]:
#         barlist[i].set_color("b")
#     else:
#         barlist[i].set_color("g")
# for i in range(10, 20):
#     barlist[i].set_color("r")
plt.ylim(0, 0.4)
plt.gca().set_xticklabels([])

# labels = ["Correct", "Grammatical but Incorrect", "Not Grammatical"]
# colors = [
#     plt.Rectangle((0, 0), 1, 1, color=label) for label in ["blue", "green", "red"]
# ]
# plt.legend(colors, labels)
# Out:
# [Text(-2.5, 0, ''),
#  Text(0.0, 0, ''),
#  Text(2.5, 0, ''),
#  Text(5.0, 0, ''),
#  Text(7.5, 0, ''),
#  Text(10.0, 0, ''),
#  Text(12.5, 0, ''),
#  Text(15.0, 0, ''),
#  Text(17.5, 0, ''),
#  Text(20.0, 0, ''),
#  Text(22.5, 0, '')]

# %%
bars1 = [0.35, 0.175, 0.125, 0.10, 0.05] + [0.2 / 15] * 15
barlist = plt.bar(list(range(1, len(bars1) + 1)), bars1)
# for i in range(1):
#     barlist[i].set_color("b")
# for i in range(1, 10):
#     barlist[i].set_color("g")
# for i in range(10, 20):
#     barlist[i].set_color("r")
plt.ylim(0, 0.4)
plt.gca().set_xticklabels([])

# labels = ["Correct", "Grammatical but Incorrect", "Not Grammatical"]
# colors = [
#     plt.Rectangle((0, 0), 1, 1, color=label) for label in ["blue", "green", "red"]
# ]
# plt.legend(colors, labels)
# Out:
# [Text(-2.5, 0, ''),
#  Text(0.0, 0, ''),
#  Text(2.5, 0, ''),
#  Text(5.0, 0, ''),
#  Text(7.5, 0, ''),
#  Text(10.0, 0, ''),
#  Text(12.5, 0, ''),
#  Text(15.0, 0, ''),
#  Text(17.5, 0, ''),
#  Text(20.0, 0, ''),
#  Text(22.5, 0, '')]

# %%
bars2 = [0.22, 0.22, 0.21, 0.10, 0.05] + [0.2 / 15] * 15
barlist = plt.bar(list(range(1, len(bars2) + 1)), bars2)
# for i in range(1):
#     barlist[i].set_color("b")
# for i in range(1, 10):
#     barlist[i].set_color("g")
# for i in range(10, 20):
#     barlist[i].set_color("r")
plt.ylim(0, 0.4)
plt.gca().set_xticklabels([])

# labels = ["Correct", "Grammatical but Incorrect", "Not Grammatical"]
# colors = [
#     plt.Rectangle((0, 0), 1, 1, color=label) for label in ["blue", "green", "red"]
# ]
# plt.legend(colors, labels)
# Out:
# [Text(-2.5, 0, ''),
#  Text(0.0, 0, ''),
#  Text(2.5, 0, ''),
#  Text(5.0, 0, ''),
#  Text(7.5, 0, ''),
#  Text(10.0, 0, ''),
#  Text(12.5, 0, ''),
#  Text(15.0, 0, ''),
#  Text(17.5, 0, ''),
#  Text(20.0, 0, ''),
#  Text(22.5, 0, '')]

# %%
bars3 = [0.4 / 3] * 3 + [0.5 / 7] * 7 + [0.1 / 10] * 10
barlist = plt.bar(list(range(1, len(bars3) + 1)), bars3)
# for i in range(1):
#     barlist[i].set_color("b")
# for i in range(1, 10):
#     barlist[i].set_color("g")
# for i in range(10, 20):
#     barlist[i].set_color("r")
plt.ylim(0, 0.4)
plt.gca().set_xticklabels([])

# labels = ["Correct", "Grammatical but Incorrect", "Not Grammatical"]
# colors = [
#     plt.Rectangle((0, 0), 1, 1, color=label) for label in ["blue", "green", "red"]
# ]
# plt.legend(colors, labels)
# Out:
# [Text(-2.5, 0, ''),
#  Text(0.0, 0, ''),
#  Text(2.5, 0, ''),
#  Text(5.0, 0, ''),
#  Text(7.5, 0, ''),
#  Text(10.0, 0, ''),
#  Text(12.5, 0, ''),
#  Text(15.0, 0, ''),
#  Text(17.5, 0, ''),
#  Text(20.0, 0, ''),
#  Text(22.5, 0, '')]

# %%
bars4 = [0.10] * 5 + [0.08] * 5 + [0.01] * 10
barlist = plt.bar(list(range(1, len(bars4) + 1)), bars4)
# for i in range(1):
#     barlist[i].set_color("b")
# for i in range(1, 10):
#     barlist[i].set_color("g")
# for i in range(10, 20):
#     barlist[i].set_color("r")
plt.ylim(0, 0.4)
plt.gca().set_xticklabels([])

# labels = ["Correct", "Grammatical but Incorrect", "Not Grammatical"]
# colors = [
#     plt.Rectangle((0, 0), 1, 1, color=label) for label in ["blue", "green", "red"]
# ]
# plt.legend(colors, labels)
# Out:
# [Text(-2.5, 0, ''),
#  Text(0.0, 0, ''),
#  Text(2.5, 0, ''),
#  Text(5.0, 0, ''),
#  Text(7.5, 0, ''),
#  Text(10.0, 0, ''),
#  Text(12.5, 0, ''),
#  Text(15.0, 0, ''),
#  Text(17.5, 0, ''),
#  Text(20.0, 0, ''),
#  Text(22.5, 0, '')]

# %%
# plot lines
x_range = range(1, 21)
plt.plot(
    list(x_range),
    [compute_largest_slope(bars0[:k], bars1[:k]) for k in x_range],
    label="Low EU, Low AU",
    linestyle="dotted",
    c="blue",
)
plt.plot(
    list(x_range),
    [compute_largest_slope(bars0[:k], bars2[:k]) for k in x_range],
    label="Low EU, High AU 1",
    linestyle="-",
    c="orange",
)
plt.plot(
    list(x_range),
    [compute_largest_slope(bars0[:k], bars3[:k]) for k in x_range],
    label="Low EU, High AU 2",
    linestyle="-",
    c="red",
)
plt.plot(
    list(x_range),
    [compute_largest_slope(bars0[:k], bars4[:k]) for k in x_range],
    label="High EU, High AU",
    linestyle="-",
    c="green",
)
plt.xticks(ticks=list(x_range))
plt.legend()
plt.title("Largest Pairwise Slope")
plt.show()
